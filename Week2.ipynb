# %%
n = int(input())
print(2 * n)
# Out:
# 12

# %%
a = float(input("chieu rong cua khu vuon"))
b = float(input("Chieu dai cua khu vuon:"))
c = a / 2
d = 3.14 * c ** 2
e = a * b - d
print("phan dien tich con lai de trong cay",round(e , 2))
# Out:
# phan dien tich con lai de trong cay 10.38

# %%
a = input()
x = ord(a)
if 65 <= x <= 90:
    print(chr(x + 32))
else:
    print(chr(x - 32))
# Out:
# r

# %%
c = input()
x = ord(c)
if 65 <= x <= 90 or 97 <= x <= 122:
    print(c, "la ki tu alphabet")
else:
    print(c, "khong la ki tu alphabet")
# Out:
# B la ki tu alphabet

# %%
a = input()
x = ord(a)
if 66<= x <= 90:
    print(chr(x + 31))
else:
    print("dac biet")
# Out:
# dac biet

# %%
a, b, c = map(float,input().split())
if a+b>c or a+c>b or b+c>a:
    d = (a+b+c)/2
    s = (d*(d-a)*(d-b)*(d-c))**0.5
    print(round(s, 1))
else:
    print("khong phai canh tam giac")
# Out:
# 94.1

# %%
a = input()
while len(a) <20 :
    a = input("a khong du do dai 20, nhap lai:")
print(a[4], a[8])
# Out:
# 3 5

# %%
x = input("ten chu ho:")
y = int(input("chi so thang truoc:"))
z = int(input("chi so thang nay:"))
t = z-y
print("Ho va ten:",x)
if t <= 50:
    print("so tien phai tra:", round((1984*t)*1.08))
elif 51<= t <= 100:
    print("so tien phai tra:", round((1984*50+2050*(t-50)*1.08)))
elif 101<= t <= 200:
    print("so tien phai tra:", round((1984*50+2050*50+2380*(t-100))*1.08))
elif 201<= t <= 300:
    print("so tien phai tra:", round((1984*50+2050*50+2380*100+2998*td-200))*1.08)
elif 301<= t <= 400:
    print("so tien phai tra:", round((1984*50+2050*50+2380*100+2998*100+3350*(t-300))*1.08))
else:
    print("so tien phai tra:", round((1984*50+2050*50+2380*100+2998*100+3350*100+3460*(t-400))*1.08))
# Out:
# Ho va ten: Son
# so tien phai tra: 23570
