# %%
print("Hello World!")
# Out:
# Hello World!

# %%
name = input("Nhap ho va ten:")
print(f"chao ban {name}")
# Out:
# chao ban Sơn

# %%
a1, b1, c1, a2, b2, a3 = map(float,input().split())
TB = (( a1 + b1 + c1 ) + ( a2 + b2 )*2 + (a3)*3)/10
print(f"{TB:.1f}")
# Out:
# 4.2

# %%
a, b = map(int,input().split())
print(a**b)
# Out:
# 426878854210636742656

# %%
chu = input("Nhap mot chu cai tu a den z:")
print(f"Ma ki tu unicode cua {chu}: {ord(chu)}")
print(f"Ki tu hoa tuong ung la: {str.upper(chu)}")
# Out:
# Ma ki tu unicode cua F: 70
# Ki tu hoa tuong ung la: F

# %%
A = ((13 ** 2) * 3) + 5
B = 13**2*3 + 5
print("A=", A)
print("B=", B)
# Out:
# A= 512
# B= 512

# %%
a = float(input("Nhiet do Celsius:"))
b = 9/5 * a + 32
print("Nhiet do Farenheit:", round(b, 2))
# Out:
# Nhiet do Farenheit: 73.4

# %%
x = float(input("Gia tien cua dong ho Son Tung mua:"))
T = x + 10 + x*0.3 + x*0.1
print("Gia tien Dat phai tra", round(T, 2))
# Out:
# Gia tien Dat phai tra 26.8

# %%
names = input("Nhap ten 3 nguoi:").split()
reverse_list = list(reversed(names))
print("Hi", reverse_list)
# Out:
# Hi ['Tiến', 'Quân', 'Sơn']

# %%
h = int(input("Nhap so gio:"))
m = int(input("Nhap so phut:"))
s = 3600 * h + 60 * m
print("Tong so giay la:", s)
# Out:
# Tong so giay la: 10980

# %%
n = int(input("Do dai canh rubik:"))
d = 6 * n
print("so mieng dan rieng le can thiet:", d)
# Out:
# so mieng dan rieng le can thiet: 270

# %%
a = int(input("nhap so a:"))
b = int(input("nhap so b:"))
c = a*b
print("hang don vi cua a*b la:", c%10)
# Out:
# hang don vi cua a*b la: 2

# %%
a = int(input("nhap so a:"))
b = int(input("nhap so b:"))
a, b = b, a
print("hoan doi a va b:")
print("a=", a)
print("b=", b)
# Out:
# hoan doi a va b:
# a= 2
# b= 3

# %%
n = int(input())
print(6 * n * (n+1) + 1)
# Out:
# 12421

# %%
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
print("   *   ")
print("  ***  ")
print(" ***** ")
# Out:
#    *
#   ***
#  *****

# %%
print("###  ##   ###  ### ")
print(" #   # #   #    # ")
print(" #   #  #  #    #")
print(" #   # #   #    #")
# Out:
# ###  ##   ###  ###
#  #   # #   #    #
#  #   #  #  #    #
#  #   # #   #    #

# %%
ngay_trong_tuan = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
for ngay in ngay_trong_tuan:
    print(ngay)
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
thang_trong_nam = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
for thang in thang_trong_nam:
    print(thang)
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
for i in range(10):
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
